# %%
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# Just a test dataframe
df = pd.DataFrame({
    "Distance": [1, 5, 10, 25, 50, 100],
    "Trips": [5000, 12000, 18000, 15000, 8000, 3000]
})

# Simple Plot
plt.plot(df["Distance"], df["Trips"], marker='o')
plt.title("Test Plot - Distance vs Trips")
plt.xlabel("Distance (miles)")
plt.ylabel("Number of Trips")
plt.grid(True)
plt.show()

# Test Linear Regression
x = df[["Distance"]]
y = df[["Trips"]] 


model = LinearRegression()
model.fit(x, y)

print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Intercept: [12927.1586287]
# Coefficient: [[-86.71702499]]
